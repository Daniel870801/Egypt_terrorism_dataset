# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('Egypt_terr.csv')
data.head()
# Out:
#    Unnamed: 0       eventid  iyear  imonth  iday  extended  country  \
# 0         133  197003140002   1970       3    14         0       60
# 1        1092  197111280001   1971      11    28         0       60
# 2        1181  197202190001   1972       2    19         0       60
# 3        5603  197712050001   1977      12     5         0       60
# 4        6797  197809300002   1978       9    30         0       60
#
#   country_txt  region                  region_txt  ... weaptype1  \
# 0       Egypt      10  Middle East & North Africa  ...         6
# 1       Egypt      10  Middle East & North Africa  ...         5
# 2       Egypt      10  Middle East & North Africa  ...         6
# 3       Egypt      10  Middle East & North Africa  ...         5
# 4       Egypt      10  Middle East & North Africa  ...         6
#
#   weaptype1_txt  nkill  property  ishostkid      dbsource  INT_LOG  INT_IDEO  \
# 0    Explosives    0.0         1        0.0          PGIS       -9        -9
# 1      Firearms    1.0         0        0.0          PGIS        1         1
# 2    Explosives    0.0         0        1.0  Hijacking DB        0         1
# 3      Firearms    1.0         0        0.0          PGIS       -9        -9
# 4    Explosives    0.0         1        0.0          PGIS        1         0
#
#    INT_MISC  INT_ANY
# 0         0       -9
# 1         0        1
# 2         1        1
# 3         1        1
# 4         1        1
#
# [5 rows x 45 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2479 entries, 0 to 2478
# Data columns (total 45 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        2479 non-null   int64
#  1   eventid           2479 non-null   int64
#  2   iyear             2479 non-null   int64
#  3   imonth            2479 non-null   int64
#  4   iday              2479 non-null   int64
#  5   extended          2479 non-null   int64
#  6   country           2479 non-null   int64
#  7   country_txt       2479 non-null   object
#  8   region            2479 non-null   int64
#  9   region_txt        2479 non-null   object
#  10  provstate         2461 non-null   object
#  11  city              2478 non-null   object
#  12  latitude          2458 non-null   float64
#  13  longitude         2458 non-null   float64
#  14  specificity       2479 non-null   float64
#  15  vicinity          2479 non-null   int64
#  16  crit1             2479 non-null   int64
#  17  crit2             2479 non-null   int64
#  18  crit3             2479 non-null   int64
#  19  doubtterr         2479 non-null   float64
#  20  multiple          2479 non-null   float64
#  21  success           2479 non-null   int64
#  22  suicide           2479 non-null   int64
#  23  attacktype1       2479 non-null   int64
#  24  attacktype1_txt   2479 non-null   object
#  25  targtype1         2479 non-null   int64
#  26  targtype1_txt     2479 non-null   object
#  27  targsubtype1      2241 non-null   float64
#  28  targsubtype1_txt  2241 non-null   object
#  29  target1           2474 non-null   object
#  30  natlty1           2479 non-null   float64
#  31  natlty1_txt       2479 non-null   object
#  32  gname             2479 non-null   object
#  33  guncertain1       2479 non-null   float64
#  34  individual        2479 non-null   int64
#  35  weaptype1         2479 non-null   int64
#  36  weaptype1_txt     2479 non-null   object
#  37  nkill             2446 non-null   float64
#  38  property          2479 non-null   int64
#  39  ishostkid         2479 non-null   float64
#  40  dbsource          2479 non-null   object
#  41  INT_LOG           2479 non-null   int64
#  42  INT_IDEO          2479 non-null   int64
#  43  INT_MISC          2479 non-null   int64
#  44  INT_ANY           2479 non-null   int64
# dtypes: float64(10), int64(23), object(12)
# memory usage: 871.6+ KB

# %%
def missingvaluesdf():

    missing_values=pd.DataFrame(data.isna().sum())

    filt=(missing_values.iloc[:,0]>0)
    return missing_values[filt]

# %% [markdown]
# Let's explore more in detail the missing data

# %%
data.loc[data.provstate.isna()==True][['provstate','city']]
# Out:
#     provstate              city
# 5         NaN           Unknown
# 7         NaN        Alexandria
# 21        NaN              Giza
# 58        NaN          Hurghada
# 66        NaN         Beni Suef
# 72        NaN          Damietta
# 109       NaN             Luxor
# 112       NaN            Faiyum
# 125       NaN         Port Said
# 163       NaN               Mir
# 176       NaN              Edfu
# 219       NaN         Abu Mawas
# 245       NaN  Izbat Sayk Basha
# 248       NaN              Idfa
# 386       NaN          Farshout
# 414       NaN             Cairo
# 418       NaN              Tima
# 420       NaN              Suez

# %%
#Having the provstate for each city would be a great help. Let's see if we can use the rest of the dataset for it
provcity=data[['provstate','city']].dropna(axis=0,how='any')

# %%
provcity.drop_duplicates(keep='first',ignore_index=True,inplace=True)

# %%
provcity.nunique()
# Out:
# provstate     43
# city         327
# dtype: int64

# %%
dict_city=provcity.set_index('city').to_dict()['provstate']

# %%
len(dict_city)
# Out:
# 327

# %%
#Now we have a dictionary {city: provstate}, we should be able to fill in the missing values in provstate
data['provstate']=data['provstate'].fillna(data['city'].apply(lambda x: dict_city.get(x)))

# %%
missing_values=pd.DataFrame(data.isna().sum())

filt=(missing_values.iloc[:,0]>0)
missing_values[filt]
# Out:
#                     0
# provstate           4
# city                1
# latitude           21
# longitude          21
# targsubtype1      238
# targsubtype1_txt  238
# target1             5
# nkill              33

# %%
#4 values missing now in provstate. Let's see if we can fill them in manually, or if we just drop them
data.loc[data['provstate'].isna()==True][['city','latitude','longitude']]
# Out:
#                  city   latitude  longitude
# 163               Mir  27.441690  30.746817
# 219         Abu Mawas  27.641389  30.849444
# 245  Izbat Sayk Basha  30.758611  31.735833
# 248              Idfa  26.571904  31.638356

# %%
#4 keys are missing, we will add them manually and update our dictionary
dict_city2={'Mir':'Asyut','Abu Mawas':'Minya','Izbat Sayk Basha':'Al Sharqia','Idfa':'Sohag'}
dict_city.update(dict_city2)

# %%
data['provstate']=data['provstate'].fillna(data['city'].apply(lambda x: dict_city.get(x)))

# %%
missing_values=pd.DataFrame(data.isna().sum())

filt=(missing_values.iloc[:,0]>0)
missing_values[filt]
# Out:
#                     0
# city                1
# latitude           21
# longitude          21
# targsubtype1      238
# targsubtype1_txt  238
# target1             5
# nkill              33

# %%
data.loc[data['city'].isna()==True][['city','latitude','longitude']]
# Out:
#     city   latitude  longitude
# 496  NaN  30.608472  33.617577

# %%
#The city is Al Hasna, let's fill it manually
data['city']=data['city'].fillna(value='Al Hasna')

# %%
missing_values=pd.DataFrame(data.isna().sum())

filt=(missing_values.iloc[:,0]>0)
missing_values[filt]
# Out:
#                     0
# latitude           21
# longitude          21
# targsubtype1      238
# targsubtype1_txt  238
# target1             5
# nkill              33

# %%
#Let's check latitude and longitude
data.loc[data.latitude.isna()==True]['city']
# Out:
# 68             Unknown
# 76             Unknown
# 79             Unknown
# 138        Upper Egypt
# 214     Southern Egypt
# 215     Southern Egypt
# 291         Edka-Hener
# 292              Hener
# 299              Esfay
# 582            Unknown
# 724            Unknown
# 725            Unknown
# 770            Unknown
# 779            Unknown
# 1057           Unknown
# 1086           Unknown
# 1172           Unknown
# 1173           Unknown
# 1610           Unknown
# 1620           Unknown
# 1836           Unknown
# Name: city, dtype: object

# %%
#Even the cities are unknown. However, we don't know for sure it will prevent us from analyzing the dataset. We should maybe first 
#replace with "0" before analyzing locations

data[['latitude','longitude']]=data[['latitude','longitude']].fillna(value=0)

# %%
missing_values=pd.DataFrame(data.isna().sum())

filt=(missing_values.iloc[:,0]>0)
missing_values[filt]
# Out:
#                     0
# targsubtype1      238
# targsubtype1_txt  238
# target1             5
# nkill              33

# %%
#Let's check targsubtype1 and targsubtype1_txt
data.loc[data.targsubtype1.isna()==True][['targtype1','targtype1_txt','targsubtype1','targsubtype1_txt']]
# Out:
#       targtype1                 targtype1_txt  targsubtype1 targsubtype1_txt
# 18           20                       Unknown           NaN              NaN
# 45            2          Government (General)           NaN              NaN
# 111           8       Educational Institution           NaN              NaN
# 273          17  Terrorists/Non-State Militia           NaN              NaN
# 276          17  Terrorists/Non-State Militia           NaN              NaN
# ...         ...                           ...           ...              ...
# 2422         20                       Unknown           NaN              NaN
# 2435         20                       Unknown           NaN              NaN
# 2458         20                       Unknown           NaN              NaN
# 2467         20                       Unknown           NaN              NaN
# 2468         20                       Unknown           NaN              NaN
#
# [238 rows x 4 columns]

# %%
data.loc[data.targtype1_txt=='Unknown'][['targtype1','targtype1_txt','targsubtype1','targsubtype1_txt']]['targtype1'].unique()
# Out:
# array([20], dtype=int64)

# %%
#The targtype 20 doesn't seem very useful, let's drop it
data=data.loc[data.targtype1!=20]

# %%
missingvaluesdf()
# Out:
#                    0
# targsubtype1      27
# targsubtype1_txt  27
# target1            5
# nkill             32

# %%
data.shape
# Out:
# (2268, 45)

# %%
data.loc[data.targsubtype1_txt.isna()==True][['targtype1','targtype1_txt','targsubtype1','targsubtype1_txt']]
# Out:
#       targtype1                   targtype1_txt  targsubtype1 targsubtype1_txt
# 45            2            Government (General)           NaN              NaN
# 111           8         Educational Institution           NaN              NaN
# 273          17    Terrorists/Non-State Militia           NaN              NaN
# 276          17    Terrorists/Non-State Militia           NaN              NaN
# 286          17    Terrorists/Non-State Militia           NaN              NaN
# 308          17    Terrorists/Non-State Militia           NaN              NaN
# 318           2            Government (General)           NaN              NaN
# 369           1                        Business           NaN              NaN
# 370           1                        Business           NaN              NaN
# 371           1                        Business           NaN              NaN
# 379           1                        Business           NaN              NaN
# 443           3                          Police           NaN              NaN
# 451          15  Religious Figures/Institutions           NaN              NaN
# 573           1                        Business           NaN              NaN
# 853          16               Telecommunication           NaN              NaN
# 1155         21                       Utilities           NaN              NaN
# 1392         16               Telecommunication           NaN              NaN
# 1403          1                        Business           NaN              NaN
# 1591          1                        Business           NaN              NaN
# 1632         16               Telecommunication           NaN              NaN
# 1694         16               Telecommunication           NaN              NaN
# 1695         16               Telecommunication           NaN              NaN
# 1706         16               Telecommunication           NaN              NaN
# 1711          1                        Business           NaN              NaN
# 1737          1                        Business           NaN              NaN
# 1890          1                        Business           NaN              NaN
# 2271          2            Government (General)           NaN              NaN

# %%
data.loc[data['targtype1_txt']=='Business']['targsubtype1_txt'].value_counts()
# Out:
# Retail/Grocery/Bakery                    48
# Bank/Commerce                            20
# Medical/Pharmaceutical                   12
# Construction                             10
# Farm/Ranch                                9
# Hotel/Resort                              9
# Restaurant/Bar/Café                       7
# Gas/Oil/Electric                          7
# Entertainment/Cultural/Stadium/Casino     5
# Industrial/Textiles/Factory               2
# Multinational Corporation                 2
# Name: targsubtype1_txt, dtype: int64

# %%
data.loc[data['targtype1_txt']=='Telecommunication']['targsubtype1_txt']
# Out:
# 809     Internet Infrastructure
# 853                         NaN
# 1041        Telephone/Telegraph
# 1319        Telephone/Telegraph
# 1392                        NaN
# 1632                        NaN
# 1694                        NaN
# 1695                        NaN
# 1706                        NaN
# Name: targsubtype1_txt, dtype: object

# %%
data.loc[data['targtype1_txt']=='Terrorists/Non-State Militia']['targsubtype1_txt'].value_counts()
# Out:
# Terrorist            3
# Non-State Militia    3
# Name: targsubtype1_txt, dtype: int64

# %%
#We can see that for the columns targsubtype, the value can't really be guessed. We will fill the np.nan by 0 and Non available
data["targsubtype1"]=data["targsubtype1"].fillna(value=0)
data["targsubtype1_txt"]=data["targsubtype1_txt"].fillna(value='Not available')

# %%
missingvaluesdf()
# Out:
#           0
# target1   5
# nkill    32

# %%
#We're almost there! target1 and nkill now

data.loc[data.target1.isna()==True][['targtype1','targtype1_txt','targsubtype1','targsubtype1_txt']]
# Out:
#      targtype1                   targtype1_txt  targsubtype1  \
# 7           15  Religious Figures/Institutions          86.0
# 8           15  Religious Figures/Institutions          86.0
# 12           6             Airports & Aircraft          42.0
# 23          11                        Maritime          58.0
# 239          2            Government (General)          21.0
#
#                         targsubtype1_txt
# 7                       Place of Worship
# 8                       Place of Worship
# 12          Aircraft (not at an airport)
# 23                   Commercial Maritime
# 239  Government Building/Facility/Office

# %%
data.loc[data['targtype1']==15]['target1'].value_counts()
# Out:
# Church                                                  17
# Mosque                                                  10
# Coptic Christian Church                                  2
# Shrine                                                   2
# Former Grand Mufti: Sheikh Ali Gomaa                     1
# Priest: Father Samaan Shehata                            1
# Sufi Cleric: Sheikh Sulayman Abu-Haraz                   1
# Saint Georges, the Two Saints and Abu Keer  churches     1
# Two Saints Church                                        1
# Coptic Bishop: Anba Makarios                             1
# Religious Compound                                       1
# group of members                                         1
# Pharonic Temple                                          1
# Church of Virgin Mary                                    1
# Coptic Church                                            1
# Sufi Leader: Sheikh Khaled al-Ratil Sawarka              1
# Latin Church                                             1
# Temple                                                   1
# Coptic Christian Priest: Rafael Moussa                   1
# Coptic Monestary of Moharrak                             1
# Sufi Clerics                                             1
# Guard at church                                          1
# Evangelical Church                                       1
# The attack targeted a church.                            1
# Coptic Priest: Mina Aboud Sharween                       1
# A synagogue                                              1
# Wedding party                                            1
# Cleric: Shaykh Sulayman Abu Hiraz                        1
# Virgin Mary Church                                       1
# Synagogue                                                1
# Christian Church                                         1
# Cleric: Anas Sultan                                      1
# Imam: Sa'id 'Abd-al-Fattah                               1
# Al-Shahid Husni al-Badawi Mosque                         1
# Coptic Christians                                        1
# Imam: Reda Abdel Bari                                    1
# Name: target1, dtype: int64

# %%
#Here as well, we can't guess... not available seems to be a right choice

data.target1=data.target1.fillna(value='Not available')

# %%
missingvaluesdf()
# Out:
#         0
# nkill  32

# %%
data.loc[data.nkill.isna()==True]
# Out:
#       Unnamed: 0       eventid  iyear  imonth  iday  extended  country  \
# 546       110960  201209160010   2012       9    16         0       60
# 573       116821  201305060031   2013       5     6         1       60
# 582       118457  201306260039   2013       6    26         1       60
# 596       118740  201307050013   2013       7     5         0       60
# 601       118786  201307060026   2013       7     6         0       60
# 654       119360  201307220043   2013       7    22         0       60
# 709       120204  201308130032   2013       8    13         0       60
# 722       120307  201308160037   2013       8    16         0       60
# 733       120482  201308220040   2013       8    22         0       60
# 1046      134121  201406300028   2014       6    30         1       60
# 1490      146285  201504010111   2015       4     1         1       60
# 1578      147346  201504260107   2015       4    26         0       60
# 1633      148611  201505260082   2015       5    26         1       60
# 1747      151105  201507270036   2015       7    27         1       60
# 1770      152008  201508190006   2015       8    19         1       60
# 1822      154242  201510150016   2015      10    15         1       60
# 2027      164179  201606280007   2016       6    28         0       60
# 2049      164702  201607130017   2016       7    13         0       60
# 2099      166033  201608150048   2016       8    15         0       60
# 2153      167376  201609230023   2016       9    23         1       60
# 2154      167406  201609240027   2016       9    24         1       60
# 2155      167407  201609240028   2016       9    24         1       60
# 2161      167616  201610010004   2016      10     1         1       60
# 2208      168827  201611030021   2016      11     3         1       60
# 2224      169235  201611130076   2016      11    13         1       60
# 2317      172682  201703050018   2017       3     5         1       60
# 2348      173859  201704120022   2017       4    12         1       60
# 2350      173980  201704170059   2017       4    16         1       60
# 2351      173981  201704170060   2017       4    16         0       60
# 2375      175248  201705260022   2017       5    26         0       60
# 2407      177878  201708120070   2017       8    12         1       60
# 2450      179908  201710220030   2017      10    22         1       60
#
#      country_txt  region                  region_txt  ... weaptype1  \
# 546        Egypt      10  Middle East & North Africa  ...         6
# 573        Egypt      10  Middle East & North Africa  ...         5
# 582        Egypt      10  Middle East & North Africa  ...         5
# 596        Egypt      10  Middle East & North Africa  ...         5
# 601        Egypt      10  Middle East & North Africa  ...         5
# 654        Egypt      10  Middle East & North Africa  ...         5
# 709        Egypt      10  Middle East & North Africa  ...         6
# 722        Egypt      10  Middle East & North Africa  ...         6
# 733        Egypt      10  Middle East & North Africa  ...         5
# 1046       Egypt      10  Middle East & North Africa  ...         5
# 1490       Egypt      10  Middle East & North Africa  ...         5
# 1578       Egypt      10  Middle East & North Africa  ...         5
# 1633       Egypt      10  Middle East & North Africa  ...        13
# 1747       Egypt      10  Middle East & North Africa  ...         5
# 1770       Egypt      10  Middle East & North Africa  ...         5
# 1822       Egypt      10  Middle East & North Africa  ...        13
# 2027       Egypt      10  Middle East & North Africa  ...         5
# 2049       Egypt      10  Middle East & North Africa  ...         6
# 2099       Egypt      10  Middle East & North Africa  ...         6
# 2153       Egypt      10  Middle East & North Africa  ...        13
# 2154       Egypt      10  Middle East & North Africa  ...        13
# 2155       Egypt      10  Middle East & North Africa  ...        13
# 2161       Egypt      10  Middle East & North Africa  ...        13
# 2208       Egypt      10  Middle East & North Africa  ...         5
# 2224       Egypt      10  Middle East & North Africa  ...        13
# 2317       Egypt      10  Middle East & North Africa  ...         6
# 2348       Egypt      10  Middle East & North Africa  ...        13
# 2350       Egypt      10  Middle East & North Africa  ...         6
# 2351       Egypt      10  Middle East & North Africa  ...         5
# 2375       Egypt      10  Middle East & North Africa  ...        13
# 2407       Egypt      10  Middle East & North Africa  ...        13
# 2450       Egypt      10  Middle East & North Africa  ...        13
#
#      weaptype1_txt  nkill  property  ishostkid                  dbsource  \
# 546     Explosives    NaN        -9        0.0  START Primary Collection
# 573       Firearms    NaN         0        1.0  START Primary Collection
# 582       Firearms    NaN        -9        1.0  START Primary Collection
# 596       Firearms    NaN         0        0.0  START Primary Collection
# 601       Firearms    NaN        -9        0.0  START Primary Collection
# 654       Firearms    NaN         0        0.0  START Primary Collection
# 709     Explosives    NaN         1        0.0  START Primary Collection
# 722     Explosives    NaN        -9        0.0  START Primary Collection
# 733       Firearms    NaN         1        0.0  START Primary Collection
# 1046      Firearms    NaN         0        1.0  START Primary Collection
# 1490      Firearms    NaN         0        1.0  START Primary Collection
# 1578      Firearms    NaN         0        0.0  START Primary Collection
# 1633       Unknown    NaN         1        1.0  START Primary Collection
# 1747      Firearms    NaN         0        1.0  START Primary Collection
# 1770      Firearms    NaN        -9        1.0  START Primary Collection
# 1822       Unknown    NaN         0        1.0  START Primary Collection
# 2027      Firearms    NaN        -9        0.0  START Primary Collection
# 2049    Explosives    NaN         1        0.0  START Primary Collection
# 2099    Explosives    NaN         0        0.0  START Primary Collection
# 2153       Unknown    NaN         0        1.0  START Primary Collection
# 2154       Unknown    NaN         0        1.0  START Primary Collection
# 2155       Unknown    NaN         0        1.0  START Primary Collection
# 2161       Unknown    NaN         0        1.0  START Primary Collection
# 2208      Firearms    NaN         0        1.0  START Primary Collection
# 2224       Unknown    NaN         0        1.0  START Primary Collection
# 2317    Explosives    NaN         0        1.0  START Primary Collection
# 2348       Unknown    NaN         0        1.0  START Primary Collection
# 2350    Explosives    NaN         0        1.0  START Primary Collection
# 2351      Firearms    NaN         1        0.0  START Primary Collection
# 2375       Unknown    NaN         1        1.0  START Primary Collection
# 2407       Unknown    NaN         0        1.0  START Primary Collection
# 2450       Unknown    NaN         0        1.0  START Primary Collection
#
#       INT_LOG  INT_IDEO  INT_MISC  INT_ANY
# 546        -9        -9         0       -9
# 573        -9        -9         0       -9
# 582        -9        -9         0       -9
# 596        -9        -9         0       -9
# 601        -9        -9         0       -9
# 654        -9        -9         0       -9
# 709        -9        -9         0       -9
# 722        -9        -9         0       -9
# 733        -9        -9         0       -9
# 1046       -9        -9         0       -9
# 1490       -9        -9         0       -9
# 1578       -9        -9         0       -9
# 1633       -9        -9         0       -9
# 1747        0         0         0        0
# 1770        0         1         1        1
# 1822        0         0         0        0
# 2027        0         0         0        0
# 2049        0         0         0        0
# 2099        0         0         0        0
# 2153        0         0         0        0
# 2154        0         0         0        0
# 2155        0         0         0        0
# 2161        0         0         0        0
# 2208        0         0         0        0
# 2224        0         1         1        1
# 2317        0         0         0        0
# 2348        0         0         0        0
# 2350        0         0         0        0
# 2351        0         0         0        0
# 2375        0         0         0        0
# 2407        0         0         0        0
# 2450       -9        -9         0       -9
#
# [32 rows x 45 columns]

# %%
#It is hard to find the number of casualties even in the press archives... given that it is only 32 lines over 2268, we can drop them
data=data.loc[data.nkill.isna()==False]

# %%
data.shape
# Out:
# (2236, 45)

# %%
missingvaluesdf()
# Out:
# Empty DataFrame
# Columns: [0]
# Index: []

# %% [markdown]
# Now that we have carefully dealt with the missing values, let's continue with the cleaning

# %%
data.iday.unique()
# Out:
# array([14, 28, 19,  5, 30,  1,  6, 15, 10,  2,  7, 13, 24, 20, 23, 18, 27,
#         3, 26,  4, 29,  8, 17, 16,  9, 12, 25, 31,  0, 11, 21, 22],
#       dtype=int64)

# %%
#We can see there is a 0, which doesn't make sense. Let's replace it with 15 (half of the month)

data.iday=data.iday.replace({0:15})

# %%
data['date']=data.iyear.astype(str)+'-'+data.imonth.astype(str)+'-'+data.iday.astype(str)

# %%
data['date']=pd.to_datetime(data['date'])

# %%
#Now we are ready to analyze the evolution of terrorism in Egypt over time

# %% [markdown]
# Let's now check the columns of numerical values to spot any outlier or weird data

# %%
data.select_dtypes(include=np.number).describe()
# Out:
#           Unnamed: 0       eventid        iyear       imonth         iday  \
# count    2236.000000  2.236000e+03  2236.000000  2236.000000  2236.000000
# mean   125515.788014  2.010171e+11  2010.105993     6.325581    15.864043
# std     41623.896427  9.132232e+08     9.134488     3.353116     8.763782
# min       133.000000  1.970031e+11  1970.000000     1.000000     1.000000
# 25%    114495.750000  2.013022e+11  2013.000000     3.000000     8.000000
# 50%    140169.500000  2.014111e+11  2014.000000     7.000000    16.000000
# 75%    154526.000000  2.015102e+11  2015.000000     9.000000    23.250000
# max    181625.000000  2.017123e+11  2017.000000    12.000000    31.000000
#
#           extended  country  region     latitude    longitude  ...  \
# count  2236.000000   2236.0  2236.0  2236.000000  2236.000000  ...
# mean      0.023256     60.0    10.0    29.901316    32.355726  ...
# std       0.150749      0.0     0.0     3.125482     3.328246  ...
# min       0.000000     60.0    10.0     0.000000     0.000000  ...
# 25%       0.000000     60.0    10.0    29.966815    31.185192  ...
# 50%       0.000000     60.0    10.0    30.968777    33.617577  ...
# 75%       0.000000     60.0    10.0    31.127890    33.803276  ...
# max       1.000000     60.0    10.0    31.441411    34.899447  ...
#
#        guncertain1   individual    weaptype1        nkill     property  \
# count  2236.000000  2236.000000  2236.000000  2236.000000  2236.000000
# mean      0.025939     0.001342     6.073345     1.695886    -0.622540
# std       0.158989     0.036613     1.826228     9.093971     3.049291
# min       0.000000     0.000000     5.000000     0.000000    -9.000000
# 25%       0.000000     0.000000     5.000000     0.000000     0.000000
# 50%       0.000000     0.000000     6.000000     0.000000     0.000000
# 75%       0.000000     0.000000     6.000000     1.000000     1.000000
# max       1.000000     1.000000    13.000000   311.000000     1.000000
#
#          ishostkid      INT_LOG     INT_IDEO     INT_MISC      INT_ANY
# count  2236.000000  2236.000000  2236.000000  2236.000000  2236.000000
# mean      0.021467    -5.347943    -5.198569     0.034884    -5.032200
# std       0.426719     4.458173     4.647668     0.183526     4.688301
# min      -9.000000    -9.000000    -9.000000     0.000000    -9.000000
# 25%       0.000000    -9.000000    -9.000000     0.000000    -9.000000
# 50%       0.000000    -9.000000    -9.000000     0.000000    -9.000000
# 75%       0.000000     0.000000     0.000000     0.000000     0.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
# [8 rows x 33 columns]

# %%
#We also see that the country and region are unique. Indeed, it is all Egypt and MENA region. Let's erase it!
to_drop=['region','region_txt','country','country_txt']

data.drop(columns=to_drop,inplace=True)

# %% [markdown]
# In addition, we noticed that some provstate have different names along the dataset. Let's harmonize them

# %%
to_replace={
            'Al Iskandariyah (Alexandria)':'Alexandria', 
            'Al Minya (Governorate)':'Minya',
            'Al Qahirah (Cairo)':'Cairo', 
            'Al Qahirah (Governorate)':'Cairo',
            'Alexandria (Governorate)':'Alexandria', 
            'Cairo (Governorate)':'Cairo',
            'North Sinai Governorate':'North Sinai', 
            'Qena':'Quena',
            "Shamal Sina' (Governorate)":'Shamal Sina',
             'South Sinai (Governorate)':'South Sinai',
            'South Sinai Governorate':'South Sinai'
            }
data['provstate']=data['provstate'].replace(to_replace=to_replace)

# %%
#Besides that, I can't spot anything strange...let's consider our dataset clean

data.to_csv(r'C:\Users\lenovo\Desktop\Projects DATA\Egypt_terrorism_dataset\clean_data.csv')
